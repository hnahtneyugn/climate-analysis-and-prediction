# %% [markdown]
# ## 0. Tiền xử lý dữ liệu
#
# Import các thư viện cần thiết để xử lý dữ liệu lưới khí hậu và thực hiện các phép tính thống kê về lượng mưa tích lũy.

# %%
import os
import gc
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['axes.unicode_minus'] = False
folder_path = r'D:\clone\merged'

# %% [markdown]
# Xây dựng hàm xử lý dữ liệu lượng mưa từ ERA5. Trong phân tích này, chúng ta thực hiện các bước quan trọng:
# - **Chuyển đổi đơn vị**: ERA5 cung cấp tốc độ mưa (m/s hoặc kg/m²/s), chúng ta nhân với 86.400 để đưa về đơn vị **mm/ngày** cho mục đích phân tích thủy văn.
# - **Phân tách tính chất mưa**:
#     - `tp` (Total Precipitation): Tổng lượng mưa.
#     - `cp` (Convective Precipitation): Mưa đối lưu, thường là mưa dông, cường độ mạnh, thời gian ngắn.
#     - `sp` (Stratiform Precipitation): Mưa tầng ($tp - cp$), thường là mưa diện rộng, kéo dài và cường độ ổn định.
# - **Tính toán tỷ lệ**: `cf` (Convective Fraction) là tỷ lệ mưa đối lưu trong tổng lượng mưa, giúp xác định tính chất của hệ thống thời tiết chi phối khu vực.

# %%
def load_and_aggregate_precip(tp_file, cp_file):
    def preprocess(ds):
        if 'valid_time' in ds.coords: ds = ds.rename({'valid_time': 'time'})
        if 'expver' in ds.dims: ds = ds.mean(dim='expver')
        return ds.sortby('time')

    ds_tp = preprocess(xr.open_dataset(os.path.join(folder_path, tp_file)))
    v_tp = list(ds_tp.data_vars)[0]
    tp_hourly = ds_tp[v_tp].mean(dim=['latitude', 'longitude']).compute()
    
    ds_cp = preprocess(xr.open_dataset(os.path.join(folder_path, cp_file)))
    v_cp = list(ds_cp.data_vars)[0]
    cp_hourly = ds_cp[v_cp].mean(dim=['latitude', 'longitude']).compute()

    # Convert kg/m2/s to mm/day (rate * 86400)
    # Daily mean rate * 86400 = total mm for the day
    df_daily = pd.DataFrame(index=tp_hourly.resample(time='1D').mean().time.values)
    df_daily['tp'] = tp_hourly.resample(time='1D').mean().values * 86400
    df_daily['cp'] = cp_hourly.resample(time='1D').mean().values * 86400
    df_daily['sp'] = df_daily['tp'] - df_daily['cp']
    df_daily['cf'] = df_daily['cp'] / (df_daily['tp'] + 1e-9)

    df_monthly = df_daily.resample('ME').mean()
    df_yearly_sum = df_daily.resample('YS').sum()
    df_yearly_mean = df_daily.resample('YS').mean()
    
    climatology = df_monthly.groupby(df_monthly.index.month).mean()
    df_monthly['month'] = df_monthly.index.month
    df_monthly['year'] = df_monthly.index.year
    df_monthly['tp_anom'] = df_monthly['tp'] - df_monthly['month'].map(climatology['tp'])

    ds_tp.close(); ds_cp.close(); gc.collect()
    return df_daily, df_monthly, df_yearly_sum, df_yearly_mean, climatology

# %% [markdown]
# Thực thi nạp dữ liệu và kiểm tra cấu trúc của DataFrame lượng mưa hàng ngày.

# %%
tp_file = 'mean_total_precipitation_rate_merged.nc'
cp_file = 'mean_convective_precipitation_rate_merged.nc'

df_daily, df_monthly, df_yearly_sum, df_yearly_mean, clim = load_and_aggregate_precip(tp_file, cp_file)
df_daily.head()
# Out:
#                   tp        cp        sp        cf
# 1980-01-01  0.136150  0.084565  0.051585  0.621119
# 1980-01-02  0.079845  0.050805  0.029040  0.636298
# 1980-01-03  0.102677  0.061040  0.041637  0.594484
# 1980-01-04  0.998320  0.321657  0.676664  0.322198
# 1980-01-05  0.720190  0.276276  0.443914  0.383615

# %% [markdown]
# ## 1. Khí hậu học lượng mưa theo mùa
#
# Biểu đồ mô tả quy luật mùa của lượng mưa tổng cộng và sự đóng góp của hai thành phần: mưa tầng và mưa đối lưu.
#
# Quan sát sự thay đổi của `sp` và `cp` giúp hiểu rõ hơn về cơ chế gây mưa theo mùa (ví dụ: mùa mưa có thể do gió mùa gây mưa tầng diện rộng, hoặc do đối lưu nhiệt gây mưa dông cục bộ).

# %%
plt.figure(figsize=(10, 6))
plt.plot(clim.index, clim['tp'], color='black', lw=2.5, label='Tổng lượng mưa (Total)')
plt.plot(clim.index, clim['sp'], color='#85B7EB', lw=2, ls='--', label='Mưa tầng (Stratiform)')
plt.plot(clim.index, clim['cp'], color='#D85A30', lw=2, ls=':', label='Mưa đối lưu (Convective)')
plt.title("1. Khí hậu học lượng mưa theo mùa")
plt.xlabel("Tháng")
plt.ylabel("Lượng mưa trung bình (mm/ngày)")
plt.xticks(range(1, 13))
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Biến động lượng mưa tổng cộng hàng năm
#
# Theo dõi tổng lượng mưa tích lũy qua 45 năm.
# - **Đường trung bình trượt 5 năm**: Giúp nhận diện các chu kỳ đa thập kỷ (như pha của ENSO).
# - **Đường xu hướng (Linear Trend)**: Kiểm định xem tổng lượng mưa tại khu vực có đang thay đổi đáng kể do tác động của biến đổi khí hậu hay không.

# %%
plt.figure(figsize=(12, 6))
x_years = df_yearly_sum.index.year
y_total = df_yearly_sum['tp']

plt.bar(x_years, y_total, color='lightgreen', alpha=0.5, label='Lượng mưa năm')
plt.plot(x_years, y_total.rolling(5, center=True).mean(), color='green', lw=2, label='Trung bình trượt 5 năm')

slope, intercept, r, p, _ = stats.linregress(x_years, y_total)
plt.plot(x_years, intercept + slope * x_years, color='red', ls='--', label=f"Xu hướng: {slope*10:.1f} mm/thập kỷ")

plt.title("2. Biến động lượng mưa tổng cộng hàng năm")
plt.xlabel("Năm")
plt.ylabel("Tổng lượng mưa (mm/năm)")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Xu hướng tỷ lệ mưa đối lưu (Convective Fraction)
#
# Tỷ lệ mưa đối lưu là một chỉ số quan trọng trong vật lý khí quyển. Nếu xu hướng này tăng (slope dương), điều đó cho thấy mặc dù tổng lượng mưa có thể không đổi, nhưng mưa đang có xu hướng trở nên "cực đoan" hơn với các trận mưa dông cường độ mạnh và đột ngột, thay thế cho mưa tầng kéo dài.

# %%
plt.figure(figsize=(12, 6))
x_years = df_yearly_mean.index.year
y_cf = df_yearly_mean['cf']

slope, intercept, r, p, _ = stats.linregress(x_years, y_cf)
sns.regplot(x=x_years, y=y_cf, scatter_kws={'alpha':0.5}, line_kws={'color':'red', 'ls':'--'})

plt.title(f"3. Xu hướng tỷ lệ mưa đối lưu (Trend: {slope*10:.4f}/decade, p={p:.4f})")
plt.xlabel("Năm")
plt.ylabel("Tỷ lệ mưa đối lưu (0-1)")
plt.show()

# %% [markdown]
# ## 4. Ma trận dị thường lượng mưa hàng tháng
#
# Heatmap cho phép nhận diện nhanh các tháng khô hạn (màu nâu - dị thường âm) và các năm lũ lụt (màu xanh lục - dị thường dương). Ma trận này cung cấp cái nhìn lịch sử về các thái cực thủy văn của khu vực nghiên cứu.

# %%
pivot = df_monthly.pivot(index='year', columns='month', values='tp_anom')
plt.figure(figsize=(15, 8))
sns.heatmap(pivot, cmap="BrBG", center=0, cbar_kws={'label': 'Dị thường (mm/ngày)'})
plt.title("4. Ma trận dị thường lượng mưa hàng tháng")
plt.show()

# %% [markdown]
# ## 5. Phân hóa tính chất mưa: Đối lưu vs Tầng
#
# Sử dụng biểu đồ Stackplot để quan sát sự tiến hóa của cấu trúc lượng mưa theo thời gian. Đây là cách trực quan để thấy sự thay đổi trong "thực đơn" lượng mưa của khu vực, liệu mưa tầng hay mưa đối lưu đang chiếm ưu thế trong các giai đoạn lịch sử khác nhau.

# %%
plt.figure(figsize=(16, 5))
plt.stackplot(df_monthly.index, 
              df_monthly['cp'], df_monthly['sp'], 
              labels=['Mưa đối lưu', 'Mưa tầng'], 
              colors=['#D85A30', '#85B7EB'])
plt.title("5. Phân hóa tính chất mưa: Đối lưu vs Tầng")
plt.ylabel("mm/ngày")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 6. Tần suất các ngày mưa cực đoan theo ngưỡng
#
# Phân tích số ngày mưa vượt qua các ngưỡng cường độ khác nhau:
# - **Mưa nhẹ (> 1mm)**
# - **Mưa vừa (> 10mm)**
# - **Mưa to (> 25mm)**
# - **Mưa rất to (> 40mm)**
# Sự gia tăng ở các ngưỡng cao thường đi kèm với nguy cơ lũ quét và ngập lụt đô thị tăng cao.

# %%
thresholds = {"Nhẹ (>1)": 1, "Vừa (>10)": 10, "To (>25)": 25, "Rất to (>40)": 40}
fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharex=True)
axes = axes.flatten()

for i, (label, thresh) in enumerate(thresholds.items()):
    counts = (df_daily['tp'] > thresh).resample('YS').sum()
    axes[i].bar(counts.index.year, counts.values, color='steelblue')
    axes[i].set_title(f"Số ngày mưa {label}")
    axes[i].set_ylabel("Số ngày")

plt.suptitle("6. Tần suất các ngày mưa cực đoan theo ngưỡng")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Sự dịch chuyển phân phối lượng mưa theo thập kỷ (ECDF)
#
# Hàm phân phối tích lũy (ECDF) trên thang Logarit giúp so sánh toàn bộ phổ lượng mưa giữa các thập kỷ. Nếu đường cong dịch chuyển sang phải ở vùng đuôi (vùng giá trị cao), điều đó xác nhận sự gia tăng của các trận mưa cực đoan trong những thập kỷ gần đây.

# %%
df_daily['decade'] = (df_daily.index.year // 10) * 10
plt.figure(figsize=(10, 6))

for decade in sorted(df_daily['decade'].unique()):
    subset = df_daily[df_daily['decade'] == decade]['tp']
    vals = subset[subset > 1].values
    sns.ecdfplot(vals, label=f"{decade}s")

plt.xscale('log')
plt.title("7. Sự dịch chuyển phân phối lượng mưa theo thập kỷ (Hàm phân phối tích lũy)")
plt.xlabel("Lượng mưa (mm/ngày) - Thang Log")
plt.ylabel("Xác suất tích lũy")
plt.legend()
plt.show()

# %% [markdown]
# ## 8. Độ dài đợt khô hạn nhất trong năm (Dry Spell Length)
#
# Chỉ số này đo lường số ngày liên tiếp không có mưa (hoặc mưa không đáng kể < 1mm). Đây là tham số sống còn trong quản lý tài nguyên nước và nông nghiệp, giúp đánh giá mức độ khốc liệt của mùa khô qua từng năm.

# %%
def get_max_dry_spell(series):
    is_dry = series < 1.0
    return (is_dry != is_dry.shift()).cumsum().where(is_dry).value_counts().max()

annual_dry = df_daily['tp'].groupby(pd.Grouper(freq='YS')).apply(get_max_dry_spell)

plt.figure(figsize=(12, 6))
plt.plot(annual_dry.index.year, annual_dry.values, marker='o', color='brown')
plt.title("8. Độ dài đợt khô hạn nhất trong năm (Dry Spell Length)")
plt.xlabel("Năm")
plt.ylabel("Số ngày liên tiếp mưa < 1mm")
plt.show()

# %%
output_dir = r'D:\GitHub\climate-analysis-and-prediction\data\precipitation'
os.makedirs(output_dir, exist_ok=True)

# ---- Main DataFrames ----
df_daily.to_parquet(f"{output_dir}/daily.parquet", compression='snappy')
df_monthly.to_parquet(f"{output_dir}/monthly.parquet", compression='snappy')

# ---- Yearly ----
df_yearly_sum.to_parquet(f"{output_dir}/yearly_sum.parquet", compression='snappy')
df_yearly_mean.to_parquet(f"{output_dir}/yearly_mean.parquet", compression='snappy')

# ---- Climatology ----
clim.to_parquet(f"{output_dir}/climatology.parquet", compression='snappy')

print("✅ Saved precipitation (all parquet)")
# Out:
# ✅ Saved precipitation (all parquet)
