# %%
# CDS API
import cdsapi

# Libraries for working with multidimensional arrays
import numpy as np
import xarray as xr

# Library for interacting with the operating system
import os

# Libraries for plotting and visualising data
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature

# Disable warnings for data download via API
import urllib3 
urllib3.disable_warnings()

# %%
ds = xr.open_dataset("../data/era5_t2m_vn.nc")
ds
# Out:
# <xarray.Dataset> Size: 407MB
# Dimensions:     (valid_time: 15510, latitude: 81, longitude: 81)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 124kB 1940-01-01 ... 2026-02-15
#   * latitude    (latitude) float64 648B 25.0 24.75 24.5 24.25 ... 5.5 5.25 5.0
#   * longitude   (longitude) float64 648B 100.0 100.2 100.5 ... 119.5 119.8 120.0
#     number      int64 8B ...
#     expver      (valid_time) <U4 248kB ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 407MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-05T09:39 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds.valid_time
# Out:
# <xarray.DataArray 'valid_time' (valid_time: 15510)> Size: 124kB
# array(['1940-01-01T00:00:00.000000000', '1940-01-02T00:00:00.000000000',
#        '1940-01-03T00:00:00.000000000', ..., '2026-02-13T00:00:00.000000000',
#        '2026-02-14T00:00:00.000000000', '2026-02-15T00:00:00.000000000'],
#       shape=(15510,), dtype='datetime64[ns]')
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 124kB 1940-01-01 ... 2026-02-15
#     number      int64 8B ...
#     expver      (valid_time) <U4 248kB ...
# Attributes:
#     long_name:      time
#     standard_name:  time
